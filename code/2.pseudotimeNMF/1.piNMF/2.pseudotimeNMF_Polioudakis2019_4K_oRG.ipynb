# %% [markdown]
# # pseudotime-informed NMF with consensus clustering
#
# **NMF_indNeuro environment**

# %% [markdown]
# # <span style="color:red">vRG_to_oRG - 4k Polioudakis 2019</span>

# %% [raw]
# Following https://github.com/dylkot/cNMF/blob/master/Tutorials/analyze_pbmc_example_data.ipynb

# %% [markdown]
# ### Loading pcw 16 data

# %%
import scanpy as sc

import pandas as pd

import seaborn as sns

import numpy as np

import matplotlib.pyplot as plt

# visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.rcParams['figure.figsize'] = (15,7)
plt.rcParams["savefig.dpi"] = 600

# %% [markdown]
# ## cNMF

# %%
# %matplotlib inline

import os
from scipy.io import mmread

import scipy.sparse as sp
from IPython.display import Image
from piNMF import cNMF

#np.random.seed(14)

# %%
# !mkdir /home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019

# %% [raw]
# !rm -r /home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019

# %%
numiter=  750 # Number of NMF replicates. Recommended ~200 for real data
numhvgenes= 4000 

countfn = '/home/jovyan/jm_jlab/data_indNeuro/2.NMF/polioudakis19_vRGtooRG_4k.h5ad'

## Results will be saved to [output_directory]/[run_name]
output_directory = '/home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019'
if not os.path.exists(output_directory):
    os.mkdir(output_directory)
run_name = '4k_oRG_polioudakis2019'

seed = 14 ## Specify a seed pseudorandom number generation for reproducibility

# %%
output_directory+"/"+run_name+"/"
# Out:
# '/home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019/4k_oRG_polioudakis2019/'

# %%
## Initialize
cnmf_obj = cNMF(output_dir=output_directory, name=run_name)

# %%
cnmf_obj.prepare(counts_fn=countfn, components=np.arange(3,7), n_iter=numiter, seed=seed, num_highvar_genes=numhvgenes)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
# Specify that the jobs are being distributed over a single worker (total_workers=1) and then launch that worker
cnmf_obj.factorize(worker_i=0, total_workers=1)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# [Worker 0]. Starting task 0.
# [Worker 0]. Starting task 1.
# [Worker 0]. Starting task 2.
# [Worker 0]. Starting task 3.
# [Worker 0]. Starting task 4.
# [Worker 0]. Starting task 5.
# [Worker 0]. Starting task 6.
# [Worker 0]. Starting task 7.
# [Worker 0]. Starting task 8.
# [Worker 0]. Starting task 9.
# [Worker 0]. Starting task 10.
# [Worker 0]. Starting task 11.
# [Worker 0]. Starting task 12.
# [Worker 0]. Starting task 13.
# [Worker 0]. Starting task 14.
# [Worker 0]. Starting task 15.
# [Worker 0]. Starting task 16.
# [Worker 0]. Starting task 17.
# [Worker 0]. Starting task 18.
# [Worker 0]. Starting task 19.
# [Worker 0]. Starting task 20.
# [Worker 0]. Starting task 21.
# [Worker 0]. Starting task 22.
# [Worker 0]. Starting task 23.
# ...

# %%
cnmf_obj.combine(skip_missing_files=True)
# Out:
# Combining factorizations for k=3.
# Combining factorizations for k=4.
# Combining factorizations for k=5.
# Combining factorizations for k=6.

# %%
cnmf_obj.k_selection_plot(close_fig=False)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
print('This saves the corresponding figure to the following file: %s' % cnmf_obj.paths['k_selection_plot'])
# Out:
# This saves the corresponding figure to the following file: /home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019/4k_oRG_polioudakis2019/4k_oRG_polioudakis2019.k_selection.png

# %%
selected_K = 4
density_threshold = 2.00

# %%
cnmf_obj.consensus(k=selected_K, 
                   density_threshold=density_threshold, 
                   show_clustering=True, 
                   close_clustergram_fig=False, refit_usage=False)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %% [markdown]
# **Removing some outliers**

# %%
density_threshold = 0.05

# %%
cnmf_obj.consensus(k=selected_K, 
                   density_threshold=density_threshold, 
                   show_clustering=True, 
                   close_clustergram_fig=False,
                   refit_usage=False)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata = sc.read(countfn)

adata.obsm['X_pca'] = np.empty([adata.shape[0], 2])
adata.obsm['X_pca'][:,0] = adata.obs['PC_1']
adata.obsm['X_pca'][:,1] = adata.obs['PC_2']
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
save_dir = output_directory+"/"+run_name

# %%
# Load high variance genes that used for cNMF
hvgs = open(save_dir+'/4k_oRG_polioudakis2019.overdispersed_genes.txt').read().split('\n')

# %%
len(hvgs)
# Out:
# 4000

# %%
usage_norm, gep_scores, gep_tpm, topgenes = cnmf_obj.load_results(K=selected_K, density_threshold=density_threshold)
usage_norm.columns = ['Usage_%d' % i for i in usage_norm.columns]

# %% [raw]
# topgenes.head(20)

# %%
print("Number of HVGs used: %d" %len(hvgs))
print("Number of genes per module: %d " %topgenes.shape[0])
# Out:
# Number of HVGs used: 4000
# Number of genes per module: 100

# %%
sc.set_figure_params(figsize=(12,6))

sns.heatmap(usage_norm.transpose(), xticklabels=False, yticklabels=True)
# Out:
# <AxesSubplot:xlabel='t'>

# %%
#For pseudotemporal ordering in heatmap
usage_norm.rename(columns={'Usage_1':"Module_3", 'Usage_2':"Module_2", 'Usage_3':"Module_1", 'Usage_4':"Module_4"}, inplace=True)
topgenes.rename(columns={1:"Module_3", 2:"Module_2", 3:"Module_1", 4:"Module_4"}, inplace=True)

# %% [raw]
# sns.heatmap(usage_norm_copy.transpose(), xticklabels=False, yticklabels=True)

# %%
usage_norm = usage_norm[['Module_1','Module_2','Module_3','Module_4']]
topgenes = topgenes[['Module_1','Module_2','Module_3','Module_4']]

# %%
sc.set_figure_params(figsize=(12,6))

pl1 = sns.heatmap(usage_norm.transpose(), xticklabels=False, yticklabels=True)
pl1.set(xlabel="pseudotime") 


figure = pl1.get_figure()    
figure.savefig(output_directory+"/"+run_name+"/modules_to_oRG_4K_piNMF.png", dpi=400)

# %% [markdown]
# **PCA plots**

# %%
usage_norm.index = np.arange(0, usage_norm.shape[0])

# %%
adata.obs.index = np.arange(0, adata.obs.shape[0])

# %%
adata.obs = pd.merge(left=adata.obs, right=usage_norm, how='left', left_index=True, right_index=True)
# Out:
# /root/miniconda/envs/NMF_indNeuro/lib/python3.7/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %% [raw]
# sc.set_figure_params(figsize=(4,4))
#
# sc.pl.pca(adata, color=usage_norm.columns, ncols=1)

# %%
sc.settings.figdir = output_directory+"/"+run_name

# %%
sc.set_figure_params(figsize=(4,4))

sc.pl.pca(adata, color=usage_norm.columns, ncols=1, save='modules_to_oRG_4K_piNMF.png')
# Out:
# WARNING: saving figure to file /home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019/4k_oRG_polioudakis2019/pcamodules_to_oRG_4K_piNMF.png

# %% [raw]
# fig, ax = plt.subplots(figsize=(8, 4))
# sns.lineplot(data=np.array(usage_norm), legend=False)
# #sns.move_legend(ax, loc='upper left', frameon=False)
# plt.show()

# %%
from gprofiler import GProfiler

# %%
gp = GProfiler(return_dataframe=True)

# %%
topgenes.shape
# Out:
# (100, 4)

# %%
for j in topgenes.columns:
    
    print("")

    print("GO analysis for %s" %j)
    tmp = gp.profile(organism='hsapiens', 
               query=topgenes[j].tolist(), no_evidences=False)
    for i in tmp['source'].value_counts().index:
        if ("GO" not in i) and ("TF" not in i):
            print(i+"____")
            print(tmp[tmp['source'] == i]['name'])
# Out:
# GO analysis for Module_1
# REAC____
# 1                               Peptide chain elongation
# 2                      Eukaryotic Translation Elongation
# 3      Response of EIF2AK4 (GCN2) to amino acid defic...
# 4                                 Viral mRNA Translation
# 5                     Eukaryotic Translation Termination
# 6                               Selenocysteine synthesis
# 7      Nonsense Mediated Decay (NMD) independent of t...
# 9               Formation of a pool of free 40S subunits
# 10     L13a-mediated translational silencing of Cerul...
# 11     SRP-dependent cotranslational protein targetin...
# 12     GTP hydrolysis and joining of the 60S ribosoma...
# 13                         Nonsense-Mediated Decay (NMD)
# 14     Nonsense Mediated Decay (NMD) enhanced by the ...
# 15                           Selenoamino acid metabolism
# 16                     Eukaryotic Translation Initiation
# 17                  Cap-dependent Translation Initiation
# ...

# %%
save_dir
# Out:
# '/home/jovyan/jm_jlab/data_indNeuro/3.NMF_data/4k_oRG_polioudakis2019/4k_oRG_polioudakis2019'

# %%
writer = pd.ExcelWriter(save_dir+"/modules_to_oRG_Polioudakis2019_4K_GOenrich_piNMF.xlsx", engine='xlsxwriter')

for j in topgenes.columns:

    print("%s" %j)
    
    tmp = gp.profile(organism='hsapiens', 
               query=topgenes[j].tolist(), no_evidences=False)
    tmp.to_excel(writer, sheet_name=str(j))

writer.close()
# Out:
# Module_1
# Module_2
# Module_3
# Module_4

# %% [raw]
# !ls /home/jovyan/jm_jlab/cNMF_dev/src/cnmf/GOenrich/

# %%
topgenes.to_csv(save_dir+"/modules_to_oRG_topgenes_Polioudakis2019_4K_piNMF.tsv", sep='\t', index=False, header=True)

# %%
usage_norm.to_csv(save_dir+'/modules_to_oRG_activation_Polioudakis2019_4K_piNMF.tsv', sep='\t', index=False, header=True)
